# %%
from app import *
import altair as alt
import pandas as pd
# Out:
# 2023-07-17 22:59:06.747
# ...
#   command:
#
#     streamlit run /home/akaash/repos/altair-streamlit-demo/.venv/lib/python3.10/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2023-07-17 22:59:06.748 No runtime found, using MemoryCacheStorageManager
# 2023-07-17 22:59:06.749 No runtime found, using MemoryCacheStorageManager

# %% [markdown]
# Disable maximum of 5000 rows.

# %%
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
full_chart.display()
# Out:
# alt.VConcatChart(...)
